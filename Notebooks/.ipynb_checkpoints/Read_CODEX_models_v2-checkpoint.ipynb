# %% [markdown]
# # ...

# %%
# Load auxiliar functions and configurations
# %run utils.ipynb
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# E:\MeGa_sYnc\Data_Science_FCUL\Thesis\Ensemble_ML\Notebooks\utils.ipynb in <module>()
#      10 models_hour_interval = CONFIG['models']['time']['hour_interval']
#      11
# ---> 12 models_temp_filename = CONFIG['models']['variables']['temperature']['file']
#
# KeyError: 'file'

# %%
# Configurations

print(models_dataset_path, models_output_path, sep='\n')


print('seasons_dict ', seasons_dict)
print('models_start_year ', models_start_year)
print('models_hour_interval ',models_hour_interval)
print('models_temp_file ', models_temp_file)
print('models_temp_filename ', models_temp_filename)
# Out:
# ..\data\models
# ..\data\models\output
# seasons_dict  {'DJF': [12, 1, 2], 'MAM': [3, 4, 5], 'JJA': [6, 7, 8], 'SON': [9, 10, 11]}
# models_start_year  1971
# models_hour_interval  3
# models_temp_file  Forc2m_TA.txt

# %%
folders, nmodels = select_models_folders(models_dataset_path, cenario)
folders, nmodels
# Out:
# (['CNRM-CERFACS-CNRM-CM5_historical_r1i1p1_CNRM-ALADIN63_v2',
#   'CNRM-CERFACS-CNRM-CM5_historical_r1i1p1_DMI-HIRHAM5_v2',
#   'CNRM-CERFACS-CNRM-CM5_historical_r1i1p1_SMHI-RCA4_v1',
#   'ICHEC-EC-EARTH_historical_r12i1p1_SMHI-RCA4_v1',
#   'ICHEC-EC-EARTH_historical_r3i1p1_DMI-HIRHAM5_v2',
#   'IPSL-IPSL-CM5A-MR_historical_r1i1p1_SMHI-RCA4_v1',
#   'MOHC-HadGEM2-ES_historical_r1i1p1_ICTP-RegCM4-6_v1',
#   'MOHC-HadGEM2-ES_historical_r1i1p1_SMHI-RCA4_v1',
#   'MPI-M-MPI-ESM-LR_historical_r1i1p1_CLMcom-ETH-COSMO-crCLIM-v1-1_v1',
#   'MPI-M-MPI-ESM-LR_historical_r1i1p1_DMI-HIRHAM5_v1',
#   'MPI-M-MPI-ESM-LR_historical_r1i1p1_ICTP-RegCM4-6_v1',
#   'MPI-M-MPI-ESM-LR_historical_r1i1p1_SMHI-RCA4_v1a',
#   'MPI-M-MPI-ESM-LR_historical_r3i1p1_GERICS-REMO2015_v1',
#   'NCC-NorESM1-M_historical_r1i1p1_CLMcom-ETH-COSMO-crCLIM-v1-1_v1',
#   'NCC-NorESM1-M_historical_r1i1p1_DMI-HIRHAM5_v3',
#   'NCC-NorESM1-M_historical_r1i1p1_GERICS-REMO2015_v1',
#   'NCC-NorESM1-M_historical_r1i1p1_SMHI-RCA4_v1'],
#  17)

# %%
all_models = get_data_models(var_filename = 'Forc2m_TA.txt')

# %%
df_model = all_models[0]
df_model.head()
# Out:
#    year  month  day season          0          3          6          9  \
# 0  2006      1    1    DJF        NaN  11.573877  11.497919  11.607233
# 1  1971      1    2    DJF  11.958276  11.939844  11.485132  11.626123
# 2  1971      1    3    DJF  11.544519   8.921289  10.041803  11.729303
# 3  1971      1    4    DJF   9.212579   9.577661   8.420038   7.210016
# 4  1971      1    5    DJF   5.736566   4.142877   3.907098   4.405695
#
#           12         15         18         21
# 0  12.477899  12.646783  12.173059  12.071863
# 1  13.270898  13.209802  12.008325  11.341425
# 2  14.040796  14.472437  11.233606  11.131281
# 3   9.850305  11.528467   8.002100   5.873376
# 4   8.222101  11.461633   7.662775   5.234552

# %%
DC = get_season_average_data_models(out_filename = 'temp_sea_avg_models')
#DC = get_season_average_data_models()
DC.shape
# Out:
# not exist
# nparray saved to file: E:\MeGa_sYnc\Data_Science_FCUL\Thesis\Ensemble_ML\Notebooks\..\data\models\output\temp_sea_avg_models.npy
# (17, 4, 8)

# %% [markdown]
# #### Testing Reloading the saved data file

# %%
# Re-load the data form binary file and confirm it's ok

DC_t = load_nparray_models('temp_sea_avg_models.npy')
assert np.in1d(DC_t, DC).all()

# %% [markdown]
# ## Plots

# %%
 plot_season_avg_temp(DC, hours_interval = 3)

# %% [markdown]
# # Working in progress

# %%
import numpy as np
from statsmodels.distributions.empirical_distribution import ECDF

ecdf = ECDF([3, 3, 1, 4])

ecdf([3, 55, 0.5, 1.5])
array([ 0.75,  1.  ,  0.  ,  0.25])

# %%
# MORE
# COMPUTE THE PDF for each model JJA joining (pooling toghether) all hours and by hour

# %%
# COMPUTE several percentiles (1,5,25,50,75,95,99) of the temperature for each model
# at each hour during JJA

# %%
# (por exemplo: qual o percentil95 da temperatura para cada model às 15h)
# AS PDFs e PERCENTIS TB PODEM SER COMPARADAS COM OBSERVACOES -> VER Perkins S-SCORE

# %% [markdown]
# ### BITs

# %%
A= np.array([[[1, 2, 3], [1, 2, 3]], [[4, 5, 6], [4, 5, 6]]])
A

# %%
A.shape

# %%
B = np.array([[7, 8, 9], [7, 8, 9]])[np.newaxis, :]
# B = B[np.newaxis, :]
B, B.shape

# %%
np.append(A, B, axis=0 )

# %%
np.r_[A,B]

# %%
a = np.array([1,2,3,4,5])
b = np.array(['x','y','g','o', 'm']) 
a, b

# %%
b[a>3]
