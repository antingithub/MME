# %% [markdown]
# # Get observations data for Lisbon
# - import data from excel files
# - clean data
# - plot time series
# - visualize time series
# - some preliminary stats

# %%
# Load auxiliar functions and configurations
# %run utils_v3.ipynb

# %%
# Configurations

print('Observational datasets: ', temp_dataset_path, temp_output_path, prec_dataset_path, prec_output_path, sep='\n')

print('seasons_dict ', seasons_dict)
# Out:
# Observational datasets:
# ..\data\observations\temp
# ..\data\observations\temp\output
# ..\data\observations\prec
# ..\data\observations\prec\output
# seasons_dict  {'DJF': [12, 1, 2], 'MAM': [3, 4, 5], 'JJA': [6, 7, 8], 'SON': [9, 10, 11]}

# %%
prec_dict_files = get_xls_files(variable = 'prec', obs_path = prec_dataset_path)
prec_years = sorted([year[1] for year in prec_dict_files.values()])
#prec_dict_files, prec_years, 
len(prec_years)
# Out:
# E:\MeGa_sYnc\Data_Science_FCUL\Thesis\Ensemble_ML\Notebooks\..\data\observations\prec\*.xls
# 30

# %%
temp_dict_files = get_xls_files(variable = 'temp', obs_path = temp_dataset_path)
temp_years = sorted([year[1] for year in temp_dict_files.values()])
#temp_dict_files, 
len(temp_years)
# Out:
# E:\MeGa_sYnc\Data_Science_FCUL\Thesis\Ensemble_ML\Notebooks\..\data\observations\temp\*.xls
# 39

# %% [markdown]
# ## Get raw data from excel files

# %% [markdown]
# ### Temperature observations only

# %%
df_raw = get_all_obs_data(temp_dict_files, 'temp', out_dir = temp_output_path)
# Out:
# file_path - E:\MeGa_sYnc\Data_Science_FCUL\Thesis\Ensemble_ML\Notebooks\..\data\observations\temp\Temp1979.xls	year - 1979	len: 365
# file_path - E:\MeGa_sYnc\Data_Science_FCUL\Thesis\Ensemble_ML\Notebooks\..\data\observations\temp\TEMP1980.xls	year - 1980	len: 366
# file_path - E:\MeGa_sYnc\Data_Science_FCUL\Thesis\Ensemble_ML\Notebooks\..\data\observations\temp\TEMP1981.xls	year - 1981	len: 365
# file_path - E:\MeGa_sYnc\Data_Science_FCUL\Thesis\Ensemble_ML\Notebooks\..\data\observations\temp\TEMP1982.xls	year - 1982	len: 365
# file_path - E:\MeGa_sYnc\Data_Science_FCUL\Thesis\Ensemble_ML\Notebooks\..\data\observations\temp\TEMP1983.xls	year - 1983	len: 365
# file_path - E:\MeGa_sYnc\Data_Science_FCUL\Thesis\Ensemble_ML\Notebooks\..\data\observations\temp\TEMP1984.xls	year - 1984	len: 366
# file_path - E:\MeGa_sYnc\Data_Science_FCUL\Thesis\Ensemble_ML\Notebooks\..\data\observations\temp\Temp1985.xls	year - 1985	len: 365
# file_path - E:\MeGa_sYnc\Data_Science_FCUL\Thesis\Ensemble_ML\Notebooks\..\data\observations\temp\temp1986.xls	year - 1986	len: 365
# file_path - E:\MeGa_sYnc\Data_Science_FCUL\Thesis\Ensemble_ML\Notebooks\..\data\observations\temp\temp87.xls	year - 1987	len: 365
# file_path - E:\MeGa_sYnc\Data_Science_FCUL\Thesis\Ensemble_ML\Notebooks\..\data\observations\temp\temp88.xls	year - 1988	len: 366
# file_path - E:\MeGa_sYnc\Data_Science_FCUL\Thesis\Ensemble_ML\Notebooks\..\data\observations\temp\temp89.xls	year - 1989	len: 365
# file_path - E:\MeGa_sYnc\Data_Science_FCUL\Thesis\Ensemble_ML\Notebooks\..\data\observations\temp\temp90.xls	year - 1990	len: 365
# file_path - E:\MeGa_sYnc\Data_Science_FCUL\Thesis\Ensemble_ML\Notebooks\..\data\observations\temp\temp91.xls	year - 1991	len: 365
# file_path - E:\MeGa_sYnc\Data_Science_FCUL\Thesis\Ensemble_ML\Notebooks\..\data\observations\temp\temp92.xls	year - 1992	len: 366
# file_path - E:\MeGa_sYnc\Data_Science_FCUL\Thesis\Ensemble_ML\Notebooks\..\data\observations\temp\temp1993.xls	year - 1993	len: 365
# file_path - E:\MeGa_sYnc\Data_Science_FCUL\Thesis\Ensemble_ML\Notebooks\..\data\observations\temp\TEMP1994.xls	year - 1994	len: 365
# file_path - E:\MeGa_sYnc\Data_Science_FCUL\Thesis\Ensemble_ML\Notebooks\..\data\observations\temp\temp1995.xls	year - 1995	len: 365
# file_path - E:\MeGa_sYnc\Data_Science_FCUL\Thesis\Ensemble_ML\Notebooks\..\data\observations\temp\TEMP1996.xls	year - 1996	len: 366
# file_path - E:\MeGa_sYnc\Data_Science_FCUL\Thesis\Ensemble_ML\Notebooks\..\data\observations\temp\TEMP1997.xls	year - 1997	len: 365
# file_path - E:\MeGa_sYnc\Data_Science_FCUL\Thesis\Ensemble_ML\Notebooks\..\data\observations\temp\TEMP 1998.xls	year - 1998	len: 365
# file_path - E:\MeGa_sYnc\Data_Science_FCUL\Thesis\Ensemble_ML\Notebooks\..\data\observations\temp\TEMP1999.xls	year - 1999	len: 365
# file_path - E:\MeGa_sYnc\Data_Science_FCUL\Thesis\Ensemble_ML\Notebooks\..\data\observations\temp\TEMP2000.xls	year - 2000	len: 366
# file_path - E:\MeGa_sYnc\Data_Science_FCUL\Thesis\Ensemble_ML\Notebooks\..\data\observations\temp\Temp 2001.xls	year - 2001	len: 365
# file_path - E:\MeGa_sYnc\Data_Science_FCUL\Thesis\Ensemble_ML\Notebooks\..\data\observations\temp\Temp2002.xls	year - 2002	len: 365
# file_path - E:\MeGa_sYnc\Data_Science_FCUL\Thesis\Ensemble_ML\Notebooks\..\data\observations\temp\Temp2003.xls	year - 2003	len: 365
# file_path - E:\MeGa_sYnc\Data_Science_FCUL\Thesis\Ensemble_ML\Notebooks\..\data\observations\temp\Temp2004.xls	year - 2004	len: 366
# file_path - E:\MeGa_sYnc\Data_Science_FCUL\Thesis\Ensemble_ML\Notebooks\..\data\observations\temp\Temp2005.xls	year - 2005	len: 365
# file_path - E:\MeGa_sYnc\Data_Science_FCUL\Thesis\Ensemble_ML\Notebooks\..\data\observations\temp\Temp2006.xls	year - 2006	len: 365
# file_path - E:\MeGa_sYnc\Data_Science_FCUL\Thesis\Ensemble_ML\Notebooks\..\data\observations\temp\Temp2007.xls	year - 2007	len: 365
# file_path - E:\MeGa_sYnc\Data_Science_FCUL\Thesis\Ensemble_ML\Notebooks\..\data\observations\temp\Temp2008.xls	year - 2008	len: 366
# file_path - E:\MeGa_sYnc\Data_Science_FCUL\Thesis\Ensemble_ML\Notebooks\..\data\observations\temp\Temp2009.xls	year - 2009	len: 365
# file_path - E:\MeGa_sYnc\Data_Science_FCUL\Thesis\Ensemble_ML\Notebooks\..\data\observations\temp\Temp2010.xls	year - 2010	len: 365
# file_path - E:\MeGa_sYnc\Data_Science_FCUL\Thesis\Ensemble_ML\Notebooks\..\data\observations\temp\Temp2011.xls	year - 2011	len: 365
# file_path - E:\MeGa_sYnc\Data_Science_FCUL\Thesis\Ensemble_ML\Notebooks\..\data\observations\temp\Temp2012.xls	year - 2012	len: 366
# file_path - E:\MeGa_sYnc\Data_Science_FCUL\Thesis\Ensemble_ML\Notebooks\..\data\observations\temp\Temp2013.xls	year - 2013	len: 365
# file_path - E:\MeGa_sYnc\Data_Science_FCUL\Thesis\Ensemble_ML\Notebooks\..\data\observations\temp\Temp2014.xls	year - 2014	len: 365
# file_path - E:\MeGa_sYnc\Data_Science_FCUL\Thesis\Ensemble_ML\Notebooks\..\data\observations\temp\Temp2015.xls	year - 2015	len: 365
# file_path - E:\MeGa_sYnc\Data_Science_FCUL\Thesis\Ensemble_ML\Notebooks\..\data\observations\temp\Temp2016.xls	year - 2016	len: 366
# file_path - E:\MeGa_sYnc\Data_Science_FCUL\Thesis\Ensemble_ML\Notebooks\..\data\observations\temp\Temp2017.xls	year - 2017	len: 365

# %%
df_raw.head()
# Out:
#    year  month  day     1     2     3     4     5     6     7  ...     15  \
# 0  1979      1    1  13.3  13.2  13.2  13.2  13.1  13.2  13.3  ...   15.9
# 1  1979      1    2  14.4  14.2  14.2  13.8  12.5  12.3  12.1  ...   14.7
# 2  1979      1    3  12.9  13.2  13.3  13.4  14.1  14.5  14.8  ...   15.7
# 3  1979      1    4  12.0  11.9  11.9  11.4  11.2  10.5  10.4  ...   13.0
# 4  1979      1    5   8.0   7.8   7.3   7.4   7.2   7.0   7.2  ...   11.3
#
#      16    17    18    19    20    21    22    23    24
# 0  15.8  16.2  15.9  15.9  15.9  15.8  15.6  15.4  14.9
# 1  14.5  14.2  13.7  13.3  13.2  13.0  12.8  12.4  12.8
# 2  14.3  13.6  12.8  12.2  12.3  12.4  12.7  12.5  12.3
# 3  12.3  11.4  10.8  10.5   9.9   9.5   9.2   8.8   8.4
# 4  11.4  11.1  11.0   9.9   9.4   9.1   9.0   8.6   9.0
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Preliminary stats

# %%
df_raw.describe()
# Out:
#               year         month           day             1             2  \
# count  14245.00000  14245.000000  14245.000000  14242.000000  14242.000000
# mean    1998.00000      6.522850     15.729870     15.278357     15.041139
# std       11.25519      3.448846      8.800499      4.214183      4.170618
# min     1979.00000      1.000000      1.000000      1.000000      2.400000
# 25%     1988.00000      4.000000      8.000000     12.000000     11.900000
# 50%     1998.00000      7.000000     16.000000     15.100000     15.000000
# 75%     2008.00000     10.000000     23.000000     18.300000     18.100000
# max     2017.00000     12.000000     31.000000     33.900000     33.400000
#
#                   3             4             5             6             7  \
# count  14242.000000  14242.000000  14242.000000  14241.000000  14242.000000
# mean      14.823655     14.622136     14.437799     14.371294     14.713311
# std        4.140831      4.120389      4.104015      4.159562      4.474308
# min        2.200000      1.600000      1.300000      1.000000      0.900000
# 25%       11.700000     11.500000     11.300000     11.200000     11.200000
# 50%       14.800000     14.600000     14.500000     14.400000     14.800000
# 75%       17.900000     17.700000     17.600000     17.600000     18.200000
# max       32.700000     30.400000     30.400000     29.300000     30.600000
#
#            ...                 15            16            17            18  \
# count      ...       14242.000000  14242.000000  14242.000000  14242.000000
# mean       ...          20.263540     19.823471     19.222904     18.461677
# std        ...           5.623522      5.553705      5.441330      5.278564
# min        ...           2.300000      2.200000      2.200000      4.300000
# 25%        ...          15.800000     15.300000     14.900000     14.200000
# 50%        ...          19.700000     19.200000     18.600000     17.900000
# 75%        ...          24.400000     23.900000     23.100000     22.200000
# max        ...          40.900000     39.200000     38.200000     38.400000
#
#                  19            20            21            22            23  \
# count  14242.000000  14242.000000  14242.000000  14242.000000  14242.000000
# mean      17.582416     16.891841     16.429834     16.085319     15.803235
# std        4.959458      4.653007      4.466385      4.369937      4.310295
# min        4.400000      4.600000      3.800000      1.400000      3.200000
# 25%       13.700000     13.200000     13.000000     12.700000     12.500000
# 50%       17.000000     16.500000     16.100000     15.900000     15.600000
# 75%       21.000000     20.100000     19.600000     19.100000     18.900000
# max       36.800000     35.100000     33.900000     32.800000     33.400000
#
#                  24
# count  14242.000000
# mean      15.540232
# std        4.254128
# min        3.200000
# 25%       12.200000
# 50%       15.350000
# 75%       18.600000
# max       34.100000
#
# [8 rows x 27 columns]

# %% [markdown]
# #### Fix 24h column: the 24h column belongs in fact to the day after and it is the 0h column

# %%
df_raw[0] = df_raw[24].shift()
df_raw.drop(24, axis=1, inplace=True)
df_raw = df_raw[df_raw.columns[:-1].insert(3,0)]

# %%
df_raw.head()
# Out:
#    year  month  day     0     1     2     3     4     5     6  ...     14  \
# 0  1979      1    1   NaN  13.3  13.2  13.2  13.2  13.1  13.2  ...   15.8
# 1  1979      1    2  14.9  14.4  14.2  14.2  13.8  12.5  12.3  ...   14.4
# 2  1979      1    3  12.8  12.9  13.2  13.3  13.4  14.1  14.5  ...   15.7
# 3  1979      1    4  12.3  12.0  11.9  11.9  11.4  11.2  10.5  ...   13.3
# 4  1979      1    5   8.4   8.0   7.8   7.3   7.4   7.2   7.0  ...   11.1
#
#      15    16    17    18    19    20    21    22    23
# 0  15.9  15.8  16.2  15.9  15.9  15.9  15.8  15.6  15.4
# 1  14.7  14.5  14.2  13.7  13.3  13.2  13.0  12.8  12.4
# 2  15.7  14.3  13.6  12.8  12.2  12.3  12.4  12.7  12.5
# 3  13.0  12.3  11.4  10.8  10.5   9.9   9.5   9.2   8.8
# 4  11.3  11.4  11.1  11.0   9.9   9.4   9.1   9.0   8.6
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Preliminary data visualization

# %%
# checking for major problems with data
df_temp = df_raw.iloc[:, 3:]
_ = plt.figure(figsize=(18,8))
_ = plt.plot(df_temp)
_ = plt.legend(df_temp.columns)

# %% [markdown]
# ### Save observations dataframe - hourly columns

# %%
save_df2csv(df_raw, 'temp_obs_1979_2005_raw.csv', temp_output_path)

# %% [markdown]
# ### Load dataframe

# %%
df_raw_ = load_csv2df('temp_obs_1979_2005_raw.csv', temp_output_path)
assert compare_saved_loaded_df(df_raw_, df_raw)

# %% [markdown]
# ### Build Time Series format

# %%
df_obs = obs_ts_format(df_raw, ['year', 'month', 'day'], 'hour', 'temp', freq_index='H')
df_obs.head()

# %% [markdown]
# ### Save all observations time series to file

# %%
save_df2csv(df_obs, 'temp_obs_1979_2005.csv', temp_output_path, index=True)

# %% [markdown]
# ### Load dataframe

# %%
df_obs_ = load_csv2df('temp_obs_1979_2005.csv', temp_output_path, freq_index='1H')
# exclude the 'season' column
assert compare_saved_loaded_df(df_obs_[[c for c in df_obs_ if c != 'season' ]], df_obs[[c for c in df_obs_ if c != 'season' ]])

# %% [markdown]
# ### Average temperature observations for each hour

# %%
mean_hourly = df_obs.groupby(df_obs.index.time).mean()
mean_hourly.index =  list(map(lambda t: t.hour, mean_hourly.index))
mean_hourly.index.name = 'hour'

_ = mean_hourly.plot(figsize=(18,8), style='-o')
_ = plt.plot(mean_hourly.mean(axis=1))
_ = plt.title("Average temperature observations for each hour." )
_ = plt.xticks(list(range(24)))

# %% [markdown]
# ## 3h aggregation

# %%
df_obs_3 = df_obs.resample('3H', label='right', base=1, loffset ='-1H').mean()
df_obs_3 = df_obs_3.asfreq('3H')                       # TODO - check the 'how' or 'method'
df_obs_3.head()
# Out:
#                           temp
# date
# 1979-01-01 00:00:00        NaN
# 1979-01-01 03:00:00  13.233333
# 1979-01-01 06:00:00  13.166667
# 1979-01-01 09:00:00  13.433333
# 1979-01-01 12:00:00  13.533333

# %%
df_obs_3.plot(figsize=(18,8))
plt.tight_layout()
plt.show();

# %%
mean_hourly_3 = df_obs_3.groupby(df_obs_3.index.time).mean()
mean_hourly_3.index =  list(map(lambda t: t.hour, mean_hourly_3.index))
mean_hourly_3.index.name = 'hour'

_ = mean_hourly_3.plot(figsize=(18,8), style='-o')
_ = plt.title("Average temperature observations for each 3h time interval (averaged)." )
_ = plt.xticks(list(range(0,22,3)))

# %% [markdown]
# ### Filter for 'JJA'

# %%
df_obs_3_jja = filter_ts_by_season(df_obs_3, 'JJA')
df_obs_3_jja = df_obs_3_jja.asfreq('3H')
df_obs_3_jja.head()
# Out:
#                           temp
# date
# 1979-06-01 00:00:00  12.933333
# 1979-06-01 03:00:00  12.233333
# 1979-06-01 06:00:00  11.933333
# 1979-06-01 09:00:00  15.533333
# 1979-06-01 12:00:00  18.900000

# %%
save_df2csv(df_obs_3_jja, 'temp_obs_3_jja.csv', temp_output_path, index=True)

# %%
df_obs_3_jja_ = load_csv2df('temp_obs_3_jja.csv', temp_output_path, freq_index='3H')
assert compare_saved_loaded_df(df_obs_3_jja_, df_obs_3_jja)

# %% [markdown]
# #### ONLY 'JJA': Temperature observations for each 3h time interval (averaged).

# %%
_ = df_obs_3_jja['1998'].plot(figsize=(18,8))
_ = plt.tight_layout()
_ = plt.title("ONLY 'JJA' and 1998: Temperature observations for each 3h time interval (averaged).")
_ = plt.show();

# %%
df_obs_3_jja = filter_ts_by_season(df_obs_3, 'JJA')
mean_hourly_jja = df_obs_3_jja.groupby(df_obs_3_jja.index.time).mean()
mean_hourly_jja.index =  list(map(lambda t: t.hour, mean_hourly_jja.index))
mean_hourly_jja.index.name = 'hour'

_ = mean_hourly_jja.plot(figsize=(18,8), style='-o')
_ = plt.title("ONLY 'JJA': Average temperature observations for each 3h time interval (averaged)." )
_ = plt.xticks(list(range(0,22,3)))

# %% [markdown]
# #### All seasons: Average temperature observations for each 3h time interval (averaged).

# %%
seas_list= []
for season in ['DJF','MAM','JJA','SON']:
    df_temp = filter_ts_by_season(df_obs_3, season)
    df = df_temp.groupby(df_temp.index.time).mean()
    df = df.rename({'temp':season}, axis=1)
    seas_list.append(df)

res=pd.concat(seas_list, axis=1)
res.index.name = 'hour'
_ = res.plot(figsize=(18,8), style='-o')
_ = plt.title("All seasons: Average temperature observations for each 3h time interval (averaged)." )
_ = plt.xticks(res.index);

# %% [markdown]
# ### Boxplots

# %%
seas_list= []
for season in ['DJF','MAM','JJA','SON']:
    df_temp = filter_ts_by_season(df_obs_3, season)
    df_temp.rename({'temp':season}, axis=1, inplace=True)
    seas_list.append(df_temp)
    df_temp.head()

df_seasons = pd.concat(seas_list, axis=1)
df_seasons['hour'] = df_seasons.index.hour
df_seasons.reset_index(drop=True, inplace=True)

# df_seasons.head()

# %%
_ = df_seasons.boxplot(by='hour', figsize=(18, 8))
plt.grid(True)

# %% [markdown]
# ###  Percentiles

# %% [markdown]
# #### by hour

# %%
# perc_hour = percentiles_table(df_obs_3_jja, 'temp_3h', by = 'hour', percentiles = [1,5,25,50,75,95,99])
# perc_hour.plot(figsize=(16, 10))
# plt.legend(loc='upper right');
# perc_hour

# %%
# perc_hour = percentiles_table(df_obs_3_jja, 'temp_3h', by = 'year', percentiles = [1,5,25,50,75,95,99])
# perc_hour.plot(figsize=(16, 10))
# plt.legend(loc='upper right');
# perc_hour

# %% [markdown]
# ## BITS

# %% [markdown]
# ##### check why 2 dataframes are different

# %%
assert df_raw_.index.equals(df_raw.index)
assert df_raw_.columns.equals(df_raw.columns)
# assert np.isin(df_raw_.values, df_raw.values).all()
# assert df_raw_.equals(df_raw)    # something is wrong! Not the data types, not the indexes

# NaN == NaN is False
df_raw_.loc[ ~(df_raw == df_raw_).all(axis=1),:]
df_raw.loc[ ~(df_raw == df_raw_).all(axis=1),:]

# for values
d = df_raw-df_raw_
d[d.any(axis=1)]

np.isclose(all_models.values, all_models_.values).all()

# %% [markdown]
# #### Check how resamplig is working for the time series

# %%
df_obs_art = df_obs[['temp']].copy()

df_obs_art['ctrl'] = list(range(1,df_obs_art.shape[0]+1))

#df_obs_art.iloc[0,1] = df_obs_art.iloc[0,0]
df_obs_art['acc'] = df_obs_art['ctrl'].cumsum(skipna=True)
df_obs_art.head(10)

# %%
# df_obs_art_3 = df_obs_art.resample('3H', label='right', base=0).sum()
df_obs_art_3 = df_obs_art.resample('3H', label='right', base=1, loffset ='-1H').sum()
df_obs_art_3.head(10)

# %%
df_obs_art_3.tail(10)
