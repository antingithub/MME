# %% [markdown]
# # Get data form models for Lisbon
# - import data from csv files
# - plot time series
# - visualize time series
# - some preliminary stats

# %%
# Load auxiliar functions and configurations
# %run utils_v3.ipynb

# %%
# Configurations used in this NB

print('models_dataset_path', models_dataset_path, sep='\t')
print('models_output_path', models_output_path, sep='\t')

print('seasons_dict', *seasons_dict.items(), sep='\n\t')
print('models_start_year\t', models_start_year)
print('models_hour_interval\t ',models_hour_interval)
print('models_temp_filename\t', models_temp_filename)
# Out:
# models_dataset_path	..\data\models
# models_output_path	..\data\models\output
# seasons_dict
# 	('DJF', [12, 1, 2])
# 	('MAM', [3, 4, 5])
# 	('JJA', [6, 7, 8])
# 	('SON', [9, 10, 11])
# models_start_year	 1971
# models_hour_interval	  3
# models_temp_filename	 Forc2m_TA.txt

# %%
folders, nmodels = select_models_folders(models_dataset_path)
folders, nmodels
# Out:
# (['CNRM-CERFACS-CNRM-CM5_historical_r1i1p1_CNRM-ALADIN63_v2',
#   'CNRM-CERFACS-CNRM-CM5_historical_r1i1p1_DMI-HIRHAM5_v2',
#   'CNRM-CERFACS-CNRM-CM5_historical_r1i1p1_SMHI-RCA4_v1',
#   'ICHEC-EC-EARTH_historical_r12i1p1_SMHI-RCA4_v1',
#   'ICHEC-EC-EARTH_historical_r3i1p1_DMI-HIRHAM5_v2',
#   'IPSL-IPSL-CM5A-MR_historical_r1i1p1_SMHI-RCA4_v1',
#   'MOHC-HadGEM2-ES_historical_r1i1p1_ICTP-RegCM4-6_v1',
#   'MOHC-HadGEM2-ES_historical_r1i1p1_SMHI-RCA4_v1',
#   'MPI-M-MPI-ESM-LR_historical_r1i1p1_CLMcom-ETH-COSMO-crCLIM-v1-1_v1',
#   'MPI-M-MPI-ESM-LR_historical_r1i1p1_DMI-HIRHAM5_v1',
#   'MPI-M-MPI-ESM-LR_historical_r1i1p1_ICTP-RegCM4-6_v1',
#   'MPI-M-MPI-ESM-LR_historical_r1i1p1_SMHI-RCA4_v1a',
#   'MPI-M-MPI-ESM-LR_historical_r3i1p1_GERICS-REMO2015_v1',
#   'NCC-NorESM1-M_historical_r1i1p1_CLMcom-ETH-COSMO-crCLIM-v1-1_v1',
#   'NCC-NorESM1-M_historical_r1i1p1_DMI-HIRHAM5_v3',
#   'NCC-NorESM1-M_historical_r1i1p1_GERICS-REMO2015_v1',
#   'NCC-NorESM1-M_historical_r1i1p1_SMHI-RCA4_v1'],
#  17)

# %% [markdown]
# ### Build a dataframe with all models

# %%
def get_data_models(dir_models = models_dataset_path, 
                    var_filename = models_temp_filename, 
                    start_timestamp = models_start_timestamp, end_timestamp = models_end_timestamp,
                    freq_timestamp = models_freq_timestamp, plot = False):
    '''
        For temperature only!! Convertion to C
        
    '''
    res = []                        # to accumulate the dataseries
    color = cycle('rbgkmc')
    folders, nmodels = select_models_folders(dir_models, period)
    for model_id, folder in enumerate(folders):
        T2m = np.loadtxt(os.path.join(dir_models, folder, var_filename)) - 273.15
        T2m = pd.Series(T2m, name = model_id, index=pd.date_range(
                                                    start = start_timestamp,
                                                    end = models_end_timestamp,
                                                    freq = freq_timestamp,
                                                    dayfirst=True ))
        if plot:
            T2m.plot(figsize=(18,8), color=next(color))
            plt.title('Model: {}'.format(model_id))
            plt.show();
        res.append(T2m) 
        
    res = pd.concat(res, axis = 1)
    res.index.name = 'date'
    
    if plot:
        res.plot(figsize=(18,8))
        plt.tight_layout()
        plt.show();
    return res

# %%
all_models = get_data_models(plot=True)

# %%
all_models.head()
# Out:
#                             0          1          2          3          4   \
# date
# 1971-01-01 03:00:00  11.573877  10.219873   7.796777   4.500085   9.082056
# 1971-01-01 06:00:00  11.497919  10.322900   7.903406   4.211206   8.324976
# 1971-01-01 09:00:00  11.607233  10.729211   8.404871   5.657648   7.947656
# 1971-01-01 12:00:00  12.477899  12.028741   9.991785  10.080072  11.111017
# 1971-01-01 15:00:00  12.646783  13.028406  10.618127  12.647058  11.988855
#
#                             5         6         7          8          9   \
# date
# 1971-01-01 03:00:00   6.736353  2.105615  0.020776  11.195581  10.585779
# 1971-01-01 06:00:00   7.406000  1.757562 -0.169775  10.853387   9.204736
# 1971-01-01 09:00:00   8.556543  2.873712  0.355463  10.313318   9.037683
# 1971-01-01 12:00:00  10.376306  5.370782  7.845361  11.161523  11.136255
# 1971-01-01 15:00:00   9.586450  7.582971  9.079462  12.543817  12.609216
#
#                             10         11         12         13         14  \
# date
# 1971-01-01 03:00:00  10.513483  11.371576   7.471094   7.883234  10.123956
# 1971-01-01 06:00:00   9.784753  10.980371   7.891016   7.256616  10.003381
# 1971-01-01 09:00:00  10.044489  10.853571   8.202570   7.702448   9.611108
# 1971-01-01 12:00:00  12.551447  11.921564  12.222345  12.046899  10.863092
# 1971-01-01 15:00:00  13.067560  12.378809  13.796655  13.591760  12.207239
#
#                             15         16
# date
# 1971-01-01 03:00:00   8.362299  12.527917
# 1971-01-01 06:00:00   8.128351  11.757471
# 1971-01-01 09:00:00   7.612054  11.273065
# 1971-01-01 12:00:00  12.230707  13.011774
# 1971-01-01 15:00:00  14.773737  14.443658

# %% [markdown]
# #### Visual inspection - All models Averaged by hour

# %%
mean_hourly = all_models.groupby(all_models.index.time).mean()
mean_hourly.index =  list(map(lambda t: t.hour, mean_hourly.index))
mean_hourly.index.name = 'hour'

_ = mean_hourly.plot(figsize=(18,8), alpha=0.2)
_ = plt.plot(mean_hourly.mean(axis=1), '-o')
_ = plt.legend(labels=list(all_models.columns)+['models_avg'], title="models",
                    loc=1, fontsize='small', fancybox=True)
_ = plt.title("Average temperature for 3h time interval. All 16 models and its average." )
_ = plt.xticks(list(range(0,22,3)))

# %% [markdown]
# #### Testing saving and reloading data

# %%
save_df2csv(all_models, 'temp_models', models_output_path, index=True)

# %%
all_models_ = load_csv2df('temp_models.csv', models_output_path, freq_index='3H')
assert compare_saved_loaded_df(all_models_, all_models)

# %% [markdown]
# ### Only for 'JJA' and [1979, 2005]

# %%
all_models_jja = all_models['1979':'2006']
all_models_jja = filter_ts_by_season(all_models_jja, 'JJA')
all_models_jja = all_models_jja.asfreq('3H')

all_models_jja.head()
# Out:
#                             0          1          2          3          4   \
# date
# 1979-06-01 00:00:00  13.419122  14.471643  14.328729  13.729150  13.672754
# 1979-06-01 03:00:00  12.501764  14.402551  12.254663  14.001581  13.041925
# 1979-06-01 06:00:00  11.911584  13.907617  11.871179  13.747766  12.438898
# 1979-06-01 09:00:00  15.474115  17.524805  18.803857  15.239832  16.544214
# 1979-06-01 12:00:00  17.844873  19.986719  24.058984  16.716211  21.106104
#
#                             5          6          7          8          9   \
# date
# 1979-06-01 00:00:00  10.644250  12.337183  10.969507  16.211725  19.048730
# 1979-06-01 03:00:00   9.791833  11.918695  10.839319  15.977960  18.184839
# 1979-06-01 06:00:00   9.561914  12.052179  10.406824  16.152734  17.723444
# 1979-06-01 09:00:00  12.460474  14.724603  15.226221  22.113336  21.220728
# 1979-06-01 12:00:00  13.730859  18.498956  18.569238  27.650629  25.784845
#
#                             10         11         12         13         14  \
# date
# 1979-06-01 00:00:00  14.766718  16.977441  12.107019  14.522089  15.005762
# 1979-06-01 03:00:00  15.022180  16.634790  11.559991  14.790338  14.716455
# 1979-06-01 06:00:00  13.791528  16.666528  11.469415  15.098444  14.315088
# 1979-06-01 09:00:00  16.057153  18.326074  15.713953  17.690302  15.798486
# 1979-06-01 12:00:00  17.785272  20.640039  18.421106  20.991083  21.013086
#
#                             15         16
# date
# 1979-06-01 00:00:00  15.043542  10.745996
# 1979-06-01 03:00:00  14.938684  11.698389
# 1979-06-01 06:00:00  15.044244  13.068018
# 1979-06-01 09:00:00  15.259332  16.350977
# 1979-06-01 12:00:00  16.919702  19.115137

# %%
all_models_jja.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 76712 entries, 1979-06-01 00:00:00 to 2005-08-31 21:00:00
# Freq: 3H
# Data columns (total 17 columns):
# 0     19872 non-null float64
# 1     19872 non-null float64
# 2     19872 non-null float64
# 3     19872 non-null float64
# 4     19872 non-null float64
# 5     19872 non-null float64
# 6     19872 non-null float64
# 7     19872 non-null float64
# 8     19872 non-null float64
# 9     19872 non-null float64
# 10    19872 non-null float64
# 11    19872 non-null float64
# 12    19872 non-null float64
# 13    19872 non-null float64
# 14    19872 non-null float64
# 15    19872 non-null float64
# 16    19872 non-null float64
# dtypes: float64(17)
# memory usage: 10.5 MB

# %%
save_df2csv(all_models_jja, 'temp_models_1979_2005_jja', models_output_path, index=True)

# %%
all_models_jja_ = load_csv2df('temp_models_1979_2005_jja.csv', models_output_path, freq_index='3H')
assert compare_saved_loaded_df(all_models_jja_, all_models_jja)

# %%
mean_hourly = all_models_jja_.groupby(all_models_jja_.index.time).mean()
mean_hourly.index =  list(map(lambda t: t.hour, mean_hourly.index))
mean_hourly.index.name = 'hour'

_ = mean_hourly.plot(figsize=(18,8), alpha=0.2)
_ = plt.plot(mean_hourly.mean(axis=1), '-o')
_ = plt.legend(labels=list(all_models_jja_.columns)+['models_avg'], title="models",
                    loc=1, fontsize='small', fancybox=True)
_ = plt.title("ONLY for 'JJA' and 1979-2005: Average temperature for 3h time interval. All 16 models and its average." )
_ = plt.xticks(list(range(0,22,3)))

# %% [markdown]
# ## Plots

# %%
 plot_season_avg_temp(DC)

# %% [markdown]
# # Working in progress

# %%
import numpy as np
from statsmodels.distributions.empirical_distribution import ECDF

ecdf = ECDF([3, 3, 1, 4])

ecdf([3, 55, 0.5, 1.5])
array([ 0.75,  1.  ,  0.  ,  0.25])

# %%
# MORE
# COMPUTE THE PDF for each model JJA joining (pooling toghether) all hours and by hour

# %%
# COMPUTE several percentiles (1,5,25,50,75,95,99) of the temperature for each model
# at each hour during JJA

# %%
# (por exemplo: qual o percentil95 da temperatura para cada model às 15h)
# AS PDFs e PERCENTIS TB PODEM SER COMPARADAS COM OBSERVACOES -> VER Perkins S-SCORE

# %% [markdown]
# ### BITs

# %%
# Paper's model names matching with the folders data

full_model_names = [name.lower() for name in folders]
full_model_names

model_names = ['CNRMCM5_ALADIN',
'MPIESM_COSMO',
'NORESM_COSMO',
'CNRMCM5_HIRHAM',
'ECEARTH_HIRHAM',
'MPIESM_HIRHAM',
'NORESM_HIRHAM',
'HADGEM_REGCM',
'MPIESM_REGCM',
'MPIESM_REMO',
'CNRMCM5_SMHIRCA',
'ECEARTH_SMHIRCA',
'HADGEM_SMHIRCA',
'IPSLCM5_SMHIRCA',
'MPIESM_SMHIRCA',
'NORESM_SMHIRCA']

model_names = [tuple(name.lower().split('_')) for name in model_names]
model_names

for name in model_names:
    for full_name in full_model_names:
        if (name[0] in full_name) and name[1] in full_name:
            print(name, full_name)

# %%
A= np.array([[[1, 2, 3], [1, 2, 3]], [[4, 5, 6], [4, 5, 6]]])
A

# %%
A.shape

# %%
B = np.array([[7, 8, 9], [7, 8, 9]])[np.newaxis, :]
# B = B[np.newaxis, :]
B, B.shape

# %%
np.append(A, B, axis=0 )

# %%
np.r_[A,B]

# %%
a = np.array([1,2,3,4,5])
b = np.array(['x','y','g','o', 'm']) 
a, b

# %%
b[a>3]

# %%
pd.DatetimeIndex(['2018-01-01', '2018-01-03', '2018-01-05'], freq='infer')

# %%
pd.Series(range(3), index=pd.date_range('2000', freq='D', periods=3))

# %%
pd.Series(range(102271), index=pd.date_range(start = '01-01-1971 03', end = '31-12-2005 21', freq='3H', dayfirst=True ))

# %% [markdown]
# ### Descriptive Stats

# %%
def get_precentiles(df, by='hour', percentiles = [1,5,25,50,75,95,99]):
    if by == 'hour':
        by = df.index.hour
    return df.groupby(by=by).describe(percentiles = np.asarray(percentiles)/100)

# %%
models_desc = get_precentiles(all_models_, by='hour', percentiles = [1,5,25,50,75,95,99])
models_desc

# %%
# model_0 = all_models_[[0]]
# model_0.head()

# %%
model_0 = all_models_[[0]]
print(model_0.shape)
model_0.head()

# %%
resampled = model_0.resample('D').agg(['mean', 'std'])#.add_suffix('_0')
resampled.shape

# %%
resampled.head()

# %%
def custom(s):
    return s.median()

d = pd.concat([model_0.resample('D').apply(custom), resampled], axis=1).loc['2004',:]
d.head()
# .plot(figsize=(18,8))

# %%
pd.concat([model_0, model_0.resample('D').agg(['mean', 'median', 'std'])], axis=1).loc['2004', ].plot()

# %%
ax = model_0['2005'].plot(figsize=(18,8));
daily_mean = model_0.resample('D').mean().add_suffix('_mean')
daily_mean['2005'].plot(ax=ax)

# %% [markdown]
# ### For one model the mean temp using rolling window

# %%
# rolling obj
model_0_90 = model_0.rolling(window=90*8).agg(['mean', 'std']).add_suffix('_90')
model_0_360 = model_0.rolling(window=360*8).agg(['mean', 'std']).add_suffix('_180')

model_0_smooth = pd.concat([model_0_90, model_0_360], axis=1)

# %%
ax = model_0.plot(color='grey', alpha=0.3)
model_0_smooth.plot(ax=ax, figsize=(18,8))
plt.legend(labels=['0', 'mean_90', 'std_90', 'mean_360', 'std_360'])
plt.title('....');

# %% [markdown]
# ### Rolling Quantiles

# %%
# rolling obj
model_0_90_q1 = model_0.rolling(window=90*8).quantile(0.01, center=True)
model_0_90_q5 = model_0.rolling(window=90*8).quantile(0.05, center=True)
model_0_90_q95 = model_0.rolling(window=90*8).quantile(0.95, center=True)
model_0_90_q99 = model_0.rolling(window=90*8).quantile(0.99, center=True)
# model_0_360 = model_0.rolling(window=360*8).agg(['mean', 'std']).add_suffix('_180')

model_0_q = pd.concat([model_0_90_q1, model_0_90_q5, model_0_90_q95, model_0_90_q99], axis=1)

# %%
ax = model_0.plot(color='grey', alpha=0.3)
model_0_q.plot(ax=ax, figsize=(18,12))
plt.legend(labels=['0', 'q_1%', 'q_5%', 'q_95%', 'q_99%'])
plt.title('....');

# %%
# just for...
# idx = ((model_0.index >= '1971') & (model_0.index < '1972')) | (model_0.index > '2004') 
idx =  (model_0.index > '2004')

ax = model_0.loc[idx,:].plot(color='grey', alpha=0.3)
model_0_q.loc[idx,:].plot(ax=ax, figsize=(18,12))
plt.legend(labels=['0', 'q_1%', 'q_5%', 'q_95%', 'q_99%'])
plt.title('....');

# %%
model_0.first('D')

# %%
model_0.diff()

# %%
price_return.sort_values().plot(kind='barh', title='Stock Price Returns')
