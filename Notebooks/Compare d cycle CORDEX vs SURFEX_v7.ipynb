# %% [markdown]
# # Compare CORDEX vs SURFEX

# %%
version = '7'

# %%
# Load auxiliar functions and configurations
filename = 'utils_v{}.ipynb'.format(version)
# %run $filename

# %%
# Configurations
print('cordex_output_path', cordex_output_path)
print('surfex_output_path', surfex_output_path)
print('temp_output_path', temp_output_path)
print('plots_output_path', plots_output_path)
print('models_markers', models_markers)
print('seasons_dict', seasons_dict)
# Out:
# cordex_output_path ..\data\cordex\output
# surfex_output_path ..\data\surfex\output
# temp_output_path ..\data\observations\temp\output
# plots_output_path ..\plots\output
# models_markers {0: ('CNRMCM5_ALADIN', '*'), 1: ('CNRMCM5_HIRHAM', '*'), 2: ('CNRMCM5_SMHIRCA', '*'), 3: ('ECEARTH_SMHIRCA', '+'), 4: ('ECEARTH_HIRHAM', '+'), 5: ('IPSLCM5-SMHIRCA', 'd'), 6: ('HADGEM_REGCM', '1'), 7: ('HADGEM_SMHIRCA', '1'), 8: ('MPIESM_COSMO', 'o'), 9: ('MPIESM_HIRHAM', 'o'), 10: ('MPIESM_REGCM', 'o'), 11: ('MPIESM_SMHIRCA', 'o'), 12: ('MPIESM_REMO', 'o'), 13: ('NORESM_COSMO', '^'), 14: ('NORESM_HIRHAM', '^'), 15: ('NORESM_REMO', '^'), 16: ('NORESM_SMHIRCA', '^'), 18: ('EnsembleBeta', '$B$'), 19: ('EnsembleAlfa', '$A$')}
# seasons_dict {'DJF': [12, 1, 2], 'MAM': [3, 4, 5], 'JJA': [6, 7, 8], 'SON': [9, 10, 11]}

# %% [markdown]
# ## 'JJA'

# %% [markdown]
# ### Loading CORDEX data from file - JJA

# %%
df_all_cordex_jja = load_csv2df('cordex_join_obs_jja.csv', cordex_output_path, freq_index='3H')
_ = plot_models_obs_hourly_mean(df_all_cordex_jja, 'cordex', 'JJA',
                    out_filename='obs_models_3h_by_h_cordex_jja',
                    out_dir = plots_output_path, 
                    sub_folder='cordex')
# Out:
#              0          1          2          3          4          5   \
# hour
# 0     16.580253  16.955157  15.949089  15.921291  17.766131  15.751545
# 3     15.650897  16.252994  15.118905  15.051568  16.992205  14.973248
# 6     15.254064  15.748060  14.746570  14.579645  16.401078  14.623936
# 9     20.380696  18.930167  19.392411  19.716078  19.785181  19.805649
# 12    24.750813  23.085859  23.611550  24.499631  24.449162  24.752476
# 15    25.852965  24.317816  24.858336  25.814836  25.782208  26.008472
# 18    22.615275  22.034147  21.845597  22.403420  23.322696  22.442110
# 21    18.232309  18.437002  17.484597  17.533865  19.381179  17.405356
#
#              6          7          8          9          10         11  \
# hour
# 0     16.683249  15.194307  16.928538  18.587653  18.245850  17.441218
# 3     16.028100  14.300699  16.478054  17.822568  17.525547  16.581736
# 6     15.552962  13.945072  16.211097  17.267193  17.003245  16.140285
# ...

# %% [markdown]
# ### Loading SURFEX data from file - JJA

# %%
df_all_surfex_jja = load_csv2df('surfex_join_obs_jja.csv', surfex_output_path, freq_index='3H')
_ = plot_models_obs_hourly_mean(df_all_surfex_jja, 'surfex', 'JJA',
                    out_filename='obs_models_3h_by_h_surfex_jja',
                    out_dir = plots_output_path, 
                    sub_folder='surfex')

# %% [markdown]
# ## 'DJF'

# %% [markdown]
# ### Loading CORDEX data from file - DJF

# %%
df_all_cordex_djf = load_csv2df('cordex_join_obs_djf.csv', cordex_output_path, freq_index='3H')
_ = plot_models_obs_hourly_mean(df_all_cordex_djf, 'cordex', 'DJF',
                    out_filename='obs_models_3h_by_h_cordex_djf',
                    out_dir = plots_output_path, 
                    sub_folder='cordex')

# %% [markdown]
# ### Loading SURFEX data from file - DJF

# %%
df_all_surfex_djf = load_csv2df('surfex_join_obs_djf.csv', surfex_output_path, freq_index='3H')
_ = plot_models_obs_hourly_mean(df_all_surfex_djf, 'surfex', 'DJZ',
                    out_filename='obs_models_3h_by_h_surfex_djf',
                    out_dir = plots_output_path, 
                    sub_folder='surfex')

# %% [markdown]
# ## 'MAM'

# %% [markdown]
# ### Loading CORDEX data from file - MAM

# %%
df_all_cordex_mam = load_csv2df('cordex_join_obs_mam.csv', cordex_output_path, freq_index='3H')
_ = plot_models_obs_hourly_mean(df_all_cordex_mam, 'cordex', 'MAM',
                    out_filename='obs_models_3h_by_h_cordex_mam',
                    out_dir = plots_output_path, 
                    sub_folder='cordex')

# %% [markdown]
# ### Loading SURFEX data from file - MAM

# %%
df_all_surfex_mam = load_csv2df('surfex_join_obs_mam.csv', surfex_output_path, freq_index='3H')
_ = plot_models_obs_hourly_mean(df_all_surfex_mam, 'surfex', 'MAM',
                    out_filename='obs_models_3h_by_h_surfex_mam',
                    out_dir = plots_output_path, 
                    sub_folder='surfex')

# %% [markdown]
# ## 'SON'

# %% [markdown]
# ### Loading CORDEX data from file - SON

# %%
df_all_cordex_son = load_csv2df('cordex_join_obs_son.csv', cordex_output_path, freq_index='3H')
_ = plot_models_obs_hourly_mean(df_all_cordex_son, 'cordex', 'son',
                    out_filename='obs_models_3h_by_h_cordex_son',
                    out_dir = plots_output_path, 
                    sub_folder='cordex')

# %% [markdown]
# ### Loading SURFEX data from file - SON

# %%
df_all_surfex_son = load_csv2df('surfex_join_obs_son.csv', surfex_output_path, freq_index='3H')
_ = plot_models_obs_hourly_mean(df_all_surfex_son, 'surfex', 'son',
                    out_filename='obs_models_3h_by_h_surfex_son',
                    out_dir = plots_output_path, 
                    sub_folder='surfex')

# %% [markdown]
# # CORDEX & SURFEX time series comparison

# %%
plot_cmp_models_obs_hourly_mean(out_filename='ts_comparison',
                                title = "Hourly averaged T$_{2m}$ for CORDEX and SURFEX models: all seasons.\n and models' average and observations",
                                out_dir = plots_output_path, 
                                sub_folder='ts_comparison')
